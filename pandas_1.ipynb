# %% [markdown]
# # Pandas Wes Kinney Book
#
#
# - Lowkey kinda sucks that I dont show any follow through on starting these projects but now I will. The goal is to have a set of 14 notebooks covering Kinney and then PRL by Bishop. Churning out an hour or two every couple of days is how to do it.
